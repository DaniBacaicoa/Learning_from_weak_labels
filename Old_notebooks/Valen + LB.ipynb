# %%
import torch
import torch.nn as nn
import numpy as np
import math

from datasets.openml_datasets import OpenML_Dataset
from datasets.torch_datasets import Torch_Dataset
from utils.weakener import Weakener
#from models.model import MLP
from models.general_model import MLP
from utils.losses import PartialLoss,CELoss,LBLoss
from utils.trainig_testing import train_and_evaluate,warm_up,ES_train_and_evaluate

# %% [markdown]
# In this case we will create 4 data structures so they contain the 4 Weak structures that support the 4 reconstruction matrices

# %%
rec_names = ['_pinv', '_opt', '_conv', '_optconv']
batch_size = 128
dataset_objects = []
weakener_objects = []

# Create dataset objects
for name in rec_names:
    dataset_name = 'Data' + name
    dataset = Torch_Dataset('mnist', batch_size=batch_size)
    dataset_objects.append(dataset)
    globals()[dataset_name] = dataset  # store dataset object in a variable with the corresponding name

# Create weakener objects
for name in rec_names:
    dataset_name = 'Data' + name
    weakener_name = 'Weak' + name
    weakener = Weakener(globals()[dataset_name].num_classes)
    weakener_objects.append(weakener)
    globals()[weakener_name] = weakener

# %%
rec_params = {'_pinv':{'optimize':False,'convex':False},
              '_opt':{'optimize':True,'convex':False},
              '_conv':{'optimize':False,'convex':True},
              '_optconv':{'optimize':True,'convex':True}}
for i,name in enumerate(rec_names):
    weakener_objects[i].generate_M('pll')
    _,train_y,_,_ =  globals()['Data'+name].get_data()
    #_,train_y,_,_ =  dataset_objects[i].get_data()
    _,_ = globals()['Weak'+name].generate_weak(train_y)
    #_,_ = weakener_objects[i].generate_weak(train_y)
    globals()['Weak'+name].virtual_matrix(convex=rec_params[name]['convex'],
                                       optimize=rec_params[name]['optimize'])
    #weakener_objects[i].virtual_matrix(convex=rec_params[name]['convex'],
    #                                   optimize=rec_params[name]['optimize'])
    globals()['Weak'+name].virtual_labels()
    #weakener_objects[i].virtual_labels()
    globals()['Data'+name].include_weak(globals()['Weak'+name].v)
    #dataset_objects[i].include_weak(weakener_objects[i].v)

# %%
def weight_allocation(net,weights):
    for name, param in net.named_parameters():
        w = name.split('.')
        w_name = 'fc'+str(int(w[1])+1)+'.'+w[2]
        param.data = weights[w_name]
    return net

# %%
#We will do the trainig for all the models
all_result = {}
all_model = {}
for i,name in enumerate(rec_names):
    trainloader, testloader = globals()['Data'+name].get_dataloader()
    mlp_feature = MLP(globals()['Data'+name].num_features,
                      [globals()['Data'+name].num_features, globals()['Data'+name].num_features, globals()['Data'+name].num_features],
                      globals()['Data'+name].num_classes, dropout_p = 0.0, bn = False, seed = 1,
                  layer_init = lambda x: nn.init.kaiming_uniform_(x, a=math.sqrt(5))
                      )
    valen_weights = torch.load('results/mnist_random')
    mlp_feature = weight_allocation(mlp_feature,valen_weights)
    optim = torch.optim.Adam(mlp_feature.parameters(),lr=1e-5)
    loss = LBLoss(k=0.5,beta=1.1)
    print('\nTraining for'+ name +'reconstruction starts:\n')
    mlp_feature, results = ES_train_and_evaluate(mlp_feature,trainloader,testloader,
                                      optimizer=optim,loss_fn=loss,num_epochs=100,patience=5)
    all_model[name] = {'model':mlp_feature,'optimizer':optim,'loss':loss}
    all_result[name] = results
# Out:
# Training for_pinvreconstruction starts:
#
# Epoch 1/100: Train Loss: 45.4167, Train Acc: 0.8315, Test Acc: 0.6930
# Epoch 36/100: Train Loss: 2.1047, Train Acc: 0.9503, Test Acc: 0.9424
# Epoch 37/100: Train Loss: 2.0937, Train Acc: 0.9506, Test Acc: 0.9411
# Epoch 38/100: Train Loss: 2.0850, Train Acc: 0.9508, Test Acc: 0.9441
# Epoch 39/100: Train Loss: 2.0767, Train Acc: 0.9517, Test Acc: 0.9440
# Epoch 40/100: Train Loss: 2.0658, Train Acc: 0.9509, Test Acc: 0.9451
# Epoch 41/100: Train Loss: 2.0566, Train Acc: 0.9513, Test Acc: 0.9426
# Epoch 42/100: Train Loss: 2.0473, Train Acc: 0.9522, Test Acc: 0.9428
# Epoch 43/100: Train Loss: 2.0370, Train Acc: 0.9512, Test Acc: 0.9423
# Epoch 44/100: Train Loss: 2.0286, Train Acc: 0.9520, Test Acc: 0.9427
# Epoch 45/100: Train Loss: 2.0189, Train Acc: 0.9525, Test Acc: 0.9422
# Epoch 46/100: Train Loss: 2.0093, Train Acc: 0.9526, Test Acc: 0.9436
# Epoch 47/100: Train Loss: 1.9997, Train Acc: 0.9524, Test Acc: 0.9411
# Epoch 48/100: Train Loss: 1.9902, Train Acc: 0.9521, Test Acc: 0.9434
# Epoch 49/100: Train Loss: 1.9800, Train Acc: 0.9524, Test Acc: 0.9419
# Epoch 50/100: Train Loss: 1.9705, Train Acc: 0.9526, Test Acc: 0.9414
# Epoch 51/100: Train Loss: 1.9605, Train Acc: 0.9522, Test Acc: 0.9433
# Train loss has not improved in 5 epochs. Stopping early...
#
# Training for_optreconstruction starts:
#
# Epoch 1/100: Train Loss: 45.8707, Train Acc: 0.8289, Test Acc: 0.6866
# Epoch 2/100: Train Loss: 4.0460, Train Acc: 0.6986, Test Acc: 0.7182
# Epoch 3/100: Train Loss: 3.4039, Train Acc: 0.7447, Test Acc: 0.7698
# Epoch 4/100: Train Loss: 3.1193, Train Acc: 0.7843, Test Acc: 0.8025
# Epoch 5/100: Train Loss: 2.9452, Train Acc: 0.8122, Test Acc: 0.8345
# Epoch 6/100: Train Loss: 2.8249, Train Acc: 0.8367, Test Acc: 0.8457
# Epoch 7/100: Train Loss: 2.7323, Train Acc: 0.8552, Test Acc: 0.8591
# Epoch 8/100: Train Loss: 2.6604, Train Acc: 0.8671, Test Acc: 0.8766
# Epoch 9/100: Train Loss: 2.5963, Train Acc: 0.8802, Test Acc: 0.8854
# Epoch 10/100: Train Loss: 2.5479, Train Acc: 0.8877, Test Acc: 0.8931
# Epoch 11/100: Train Loss: 2.5057, Train Acc: 0.8962, Test Acc: 0.9007
# Epoch 12/100: Train Loss: 2.4692, Train Acc: 0.9032, Test Acc: 0.9063
# Epoch 13/100: Train Loss: 2.4388, Train Acc: 0.9075, Test Acc: 0.9096
# Epoch 14/100: Train Loss: 2.4102, Train Acc: 0.9134, Test Acc: 0.9104
# Epoch 15/100: Train Loss: 2.3848, Train Acc: 0.9174, Test Acc: 0.9169
# Epoch 16/100: Train Loss: 2.3636, Train Acc: 0.9207, Test Acc: 0.9219
# Epoch 17/100: Train Loss: 2.3438, Train Acc: 0.9246, Test Acc: 0.9227
# Epoch 18/100: Train Loss: 2.3251, Train Acc: 0.9266, Test Acc: 0.9221
# Epoch 19/100: Train Loss: 2.3069, Train Acc: 0.9300, Test Acc: 0.9275
# Epoch 20/100: Train Loss: 2.2915, Train Acc: 0.9322, Test Acc: 0.9311
# Epoch 21/100: Train Loss: 2.2756, Train Acc: 0.9344, Test Acc: 0.9298
# Epoch 22/100: Train Loss: 2.2612, Train Acc: 0.9365, Test Acc: 0.9307
# Epoch 23/100: Train Loss: 2.2491, Train Acc: 0.9365, Test Acc: 0.9311
# Epoch 24/100: Train Loss: 2.2363, Train Acc: 0.9385, Test Acc: 0.9363
# Epoch 25/100: Train Loss: 2.2234, Train Acc: 0.9407, Test Acc: 0.9327
# Epoch 26/100: Train Loss: 2.2119, Train Acc: 0.9415, Test Acc: 0.9368
# Epoch 27/100: Train Loss: 2.1997, Train Acc: 0.9413, Test Acc: 0.9380
# Epoch 28/100: Train Loss: 2.1898, Train Acc: 0.9431, Test Acc: 0.9362
# Epoch 29/100: Train Loss: 2.1809, Train Acc: 0.9437, Test Acc: 0.9364
# Epoch 30/100: Train Loss: 2.1677, Train Acc: 0.9449, Test Acc: 0.9381
# Epoch 31/100: Train Loss: 2.1579, Train Acc: 0.9455, Test Acc: 0.9379
# Epoch 32/100: Train Loss: 2.1501, Train Acc: 0.9451, Test Acc: 0.9368
# Epoch 33/100: Train Loss: 2.1387, Train Acc: 0.9461, Test Acc: 0.9405
# Epoch 34/100: Train Loss: 2.1291, Train Acc: 0.9469, Test Acc: 0.9408
# Epoch 35/100: Train Loss: 2.1196, Train Acc: 0.9474, Test Acc: 0.9359
# Epoch 36/100: Train Loss: 2.1107, Train Acc: 0.9476, Test Acc: 0.9396
# Epoch 37/100: Train Loss: 2.0998, Train Acc: 0.9479, Test Acc: 0.9376
# Epoch 38/100: Train Loss: 2.0911, Train Acc: 0.9490, Test Acc: 0.9376
# Epoch 39/100: Train Loss: 2.0826, Train Acc: 0.9489, Test Acc: 0.9389
# Epoch 40/100: Train Loss: 2.0719, Train Acc: 0.9489, Test Acc: 0.9378
# Epoch 41/100: Train Loss: 2.0651, Train Acc: 0.9495, Test Acc: 0.9401
# Epoch 42/100: Train Loss: 2.0537, Train Acc: 0.9498, Test Acc: 0.9402
# Epoch 43/100: Train Loss: 2.0446, Train Acc: 0.9495, Test Acc: 0.9378
# Epoch 44/100: Train Loss: 2.0362, Train Acc: 0.9488, Test Acc: 0.9399
# Epoch 45/100: Train Loss: 2.0262, Train Acc: 0.9507, Test Acc: 0.9386
# Epoch 46/100: Train Loss: 2.0182, Train Acc: 0.9494, Test Acc: 0.9389
# Epoch 47/100: Train Loss: 2.0087, Train Acc: 0.9507, Test Acc: 0.9403
# Epoch 48/100: Train Loss: 1.9978, Train Acc: 0.9505, Test Acc: 0.9405
# Epoch 49/100: Train Loss: 1.9868, Train Acc: 0.9503, Test Acc: 0.9407
# Epoch 50/100: Train Loss: 1.9786, Train Acc: 0.9504, Test Acc: 0.9381
# Train loss has not improved in 5 epochs. Stopping early...
#
# Training for_convreconstruction starts:
#
# Epoch 36/100: Train Loss: 2.1131, Train Acc: 0.9494, Test Acc: 0.9434
# Epoch 37/100: Train Loss: 2.1025, Train Acc: 0.9504, Test Acc: 0.9424
# Epoch 38/100: Train Loss: 2.0928, Train Acc: 0.9502, Test Acc: 0.9435
# Epoch 39/100: Train Loss: 2.0850, Train Acc: 0.9505, Test Acc: 0.9417
# Epoch 40/100: Train Loss: 2.0744, Train Acc: 0.9518, Test Acc: 0.9405
# Epoch 41/100: Train Loss: 2.0671, Train Acc: 0.9519, Test Acc: 0.9428
# Epoch 42/100: Train Loss: 2.0570, Train Acc: 0.9527, Test Acc: 0.9441
# Epoch 43/100: Train Loss: 2.0480, Train Acc: 0.9522, Test Acc: 0.9433
# Epoch 44/100: Train Loss: 2.0383, Train Acc: 0.9520, Test Acc: 0.9404
# Epoch 45/100: Train Loss: 2.0284, Train Acc: 0.9525, Test Acc: 0.9432
# Epoch 46/100: Train Loss: 2.0195, Train Acc: 0.9526, Test Acc: 0.9419
# Epoch 47/100: Train Loss: 2.0088, Train Acc: 0.9528, Test Acc: 0.9433
# Epoch 48/100: Train Loss: 2.0023, Train Acc: 0.9526, Test Acc: 0.9420
# Epoch 49/100: Train Loss: 1.9897, Train Acc: 0.9530, Test Acc: 0.9438
# Epoch 50/100: Train Loss: 1.9801, Train Acc: 0.9527, Test Acc: 0.9424
# Epoch 51/100: Train Loss: 1.9701, Train Acc: 0.9522, Test Acc: 0.9426
# Epoch 52/100: Train Loss: 1.9619, Train Acc: 0.9534, Test Acc: 0.9388
# Epoch 53/100: Train Loss: 1.9505, Train Acc: 0.9524, Test Acc: 0.9422
# Epoch 54/100: Train Loss: 1.9415, Train Acc: 0.9526, Test Acc: 0.9402
# Epoch 55/100: Train Loss: 1.9311, Train Acc: 0.9526, Test Acc: 0.9385
# Epoch 56/100: Train Loss: 1.9203, Train Acc: 0.9528, Test Acc: 0.9411
# Epoch 57/100: Train Loss: 1.9108, Train Acc: 0.9529, Test Acc: 0.9420
# Train loss has not improved in 5 epochs. Stopping early...
#
# Training for_optconvreconstruction starts:
#
# Epoch 1/100: Train Loss: 45.4763, Train Acc: 0.8288, Test Acc: 0.6912
# Epoch 2/100: Train Loss: 4.0484, Train Acc: 0.7054, Test Acc: 0.7249
# Epoch 3/100: Train Loss: 3.4059, Train Acc: 0.7505, Test Acc: 0.7753
# Epoch 4/100: Train Loss: 3.1238, Train Acc: 0.7888, Test Acc: 0.8080
# Epoch 5/100: Train Loss: 2.9488, Train Acc: 0.8174, Test Acc: 0.8317
# Epoch 6/100: Train Loss: 2.8263, Train Acc: 0.8398, Test Acc: 0.8505
# Epoch 7/100: Train Loss: 2.7385, Train Acc: 0.8543, Test Acc: 0.8622
# Epoch 8/100: Train Loss: 2.6637, Train Acc: 0.8687, Test Acc: 0.8775
# Epoch 9/100: Train Loss: 2.6031, Train Acc: 0.8802, Test Acc: 0.8877
# Epoch 10/100: Train Loss: 2.5514, Train Acc: 0.8893, Test Acc: 0.8975
# Epoch 11/100: Train Loss: 2.5087, Train Acc: 0.8982, Test Acc: 0.9008
# Epoch 46/100: Train Loss: 2.0093, Train Acc: 0.9517, Test Acc: 0.9423
# Epoch 47/100: Train Loss: 2.0011, Train Acc: 0.9511, Test Acc: 0.9431
# Epoch 48/100: Train Loss: 1.9917, Train Acc: 0.9509, Test Acc: 0.9427
# Epoch 49/100: Train Loss: 1.9814, Train Acc: 0.9510, Test Acc: 0.9428
# Epoch 50/100: Train Loss: 1.9707, Train Acc: 0.9519, Test Acc: 0.9443
# Epoch 51/100: Train Loss: 1.9624, Train Acc: 0.9513, Test Acc: 0.9407
# Epoch 52/100: Train Loss: 1.9514, Train Acc: 0.9508, Test Acc: 0.9413
# Epoch 53/100: Train Loss: 1.9398, Train Acc: 0.9516, Test Acc: 0.9431
# Epoch 54/100: Train Loss: 1.9298, Train Acc: 0.9507, Test Acc: 0.9409
# Epoch 55/100: Train Loss: 1.9215, Train Acc: 0.9510, Test Acc: 0.9409
# Train loss has not improved in 5 epochs. Stopping early...

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.lines import Line2D

tableau_palette = mcolors.TABLEAU_COLORS

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
colors = list(tableau_palette.values())

# Plot the first subplot (Train Loss)
for i,name in enumerate(rec_names):
    ax1.plot(all_result[name]['train_loss'],label='Train'+name,color=colors[i])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.set_title('Train Loss')


# Plot the second subplot (Accuracies)
for i,name in enumerate(rec_names):
    ax2.plot(all_result[name]['train_acc'], label='Train Accuracy'+name,
             color=colors[i])
    ax2.plot(all_result[name]['test_acc'], label='Test Accuracy'+name,
             color=colors[i],linestyle='--')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_title('Accuracies')
#ax2.legend()
legend_elements = [Line2D([0], [0], linestyle='-', color='black', label='Train Accuracy'),
                   Line2D([0], [0], linestyle='--', color='black', label='Test Accuracy')]
ax2.legend(handles=legend_elements)

fig.suptitle('CE Learning Results', fontsize=18, fontweight='bold', y=1.05)
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.lines import Line2D

tableau_palette = mcolors.TABLEAU_COLORS

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
colors = list(tableau_palette.values())

# Plot the first subplot (Train Loss)
for i,name in enumerate(rec_names):
    ax1.plot(all_result[name]['train_loss'][1:],label='Train'+name,color=colors[i])
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.set_title('Train Loss')


# Plot the second subplot (Accuracies)
for i,name in enumerate(rec_names):
    ax2.plot(all_result[name]['train_acc'], label='Train Accuracy'+name,
             color=colors[i])
    ax2.plot(all_result[name]['test_acc'], label='Test Accuracy'+name,
             color=colors[i],linestyle='--')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.set_title('Accuracies')
#ax2.legend()
legend_elements = [Line2D([0], [0], linestyle='-', color='black', label='Train Accuracy'),
                   Line2D([0], [0], linestyle='--', color='black', label='Test Accuracy')]
ax2.legend(handles=legend_elements)

fig.suptitle('CE Learning Results', fontsize=18, fontweight='bold', y=1.05)
# Show the plot
plt.show()
